# %%
import tushare as ts

import pandas as pd
from pandas import Series
import numpy as np

import pyecharts.options as opts
from pyecharts.charts import Bar
from pyecharts.charts import Map,Geo
from pyecharts import options as opts

# %%
#1.根据任务 4 所统计的上海各个区的房均价数据，利用 Pyecharts 中的 Map，以上海地图为背景作可视化展示图 

f=open("Task_4_lianjia_sale.csv")
df = pd.read_csv(f)
df_avg= df.groupby('区域')["价格"].agg({"区域平均价格":"mean"}).round(2).sort_values(by ="区域平均价格")

districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区 ', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
prices = df_avg["区域平均价格"].tolist()
lst = [[districts[i],prices[i]] for i in range(len(prices))]  
print(lst)

map_1 = Map()
map_1.set_global_opts(
    title_opts = opts.TitleOpts(title = "上海各区房屋均价"),
    visualmap_opts  = opts.VisualMapOpts(max_=100000)
)
map_1.add("链家_上海各地区房屋均价",lst,maptype="上海")   
map_1.render_notebook()
# Out:
# [['金山区', 19304.82], ['奉贤区', 23662.13], ['嘉定区', 36461.72], ['松江区', 36587.69], ['青浦区', 37078.86], ['宝山区', 42577.8], ['闵行区 ', 49080.59], ['浦东新区', 55413.06], ['普陀区', 57943.13], ['杨浦区', 62726.67], ['虹口区', 66165.35], ['长宁区', 72099.62], ['静安区', 74304.77], ['徐汇区', 75395.94], ['黄浦区', 95015.09]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="dca4c39ae6524b48a18693b26c4d48a4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_dca4c39ae6524b48a18693b26c4d48a4 = echarts.init(
#                     document.getElementById('dca4c39ae6524b48a18693b26c4d48a4'), 'white', {renderer: 'canvas'});
#                 var option_dca4c39ae6524b48a18693b26c4d48a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
# ...

# %%
# 2.导入 tushare 数据包，提取 A 股基本数据信息，利用 groupby 函数统计每个省份的公司数量，并以中国地图 为背景作相应图表
df = ts.get_stock_basics()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ...

# %%
 
df_area = df.groupby('area')['pe'].agg({"各地区企业数量":"count"})
area = df_area.index.tolist()
count = df_area["各地区企业数量"].tolist()
lst2 = [[area[i],count[i]] for i in range(len(count))]
lst2.append(["内蒙古",25])

map_2 = Map()
map_2.set_global_opts(
    title_opts = opts.TitleOpts(title = "各地区企业数量"),
    visualmap_opts  = opts.VisualMapOpts(max_=500)
)
map_2.add("Toshare_各地区企业数量",lst2,maptype="china")   
map_2.render_notebook()
# Out:
# [['上海', 306], ['云南', 36], ['内蒙', 25], ['北京', 349], ['吉林', 42], ['四川', 126], ['天津', 54], ['宁夏', 14], ['安徽', 107], ['山东', 209], ['山西', 37], ['广东', 325], ['广西', 38], ['新疆', 55], ['江苏', 432], ['江西', 44], ['河北', 57], ['河南', 80], ['浙江', 465], ['海南', 31], ['深圳', 302], ['湖北', 108], ['湖南', 106], ['甘肃', 33], ['福建', 141], ['西藏', 19], ['贵州', 29], ['辽宁', 74], ['重庆', 53], ['陕西', 53], ['青海', 12], ['黑龙江', 38], ['内蒙古', 25]]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="28fa0f8ed9c34ac5a93cf15f3ca0a9b4" style="width:900px; height:500px;"></div>
#
# <script>
# ...
