# %%
import pandas as pd
from pandas import Series
import numpy as np

import pyecharts.options as opts
from pyecharts.charts import Bar

# %%
# 1、读取 Task_4_lianjia_sale.csv 数据(阅读参考文章 2、3)，利用 groupby 函数，以【区域】字段进行 groupby， 同时结合 agg 聚合函数统计各个区域平均房价;
    #将统计所得平均房价命名为【区域平均价格】列 (阅读参考文章 4、5)
    #并将数据从小到大按顺序排列(提示:df.sort_values(by = “ ”) (阅读参考文章 6));
    #最后展示所得前 5 行数据 (将所得的 DataFrame 命名为 df_avg);

f=open("data/Task_4_lianjia_sale.csv")
df = pd.read_csv(f)
df_avg= df.groupby('区域')["价格"].agg({"区域平均价格":"mean"}).round(2).sort_values(by ="区域平均价格")
df_avg.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#       区域平均价格
# 区域
# 金山  19304.82
# 奉贤  23662.13
# 松江  36461.72
# 嘉定  36587.69
# 青浦  37078.86

# %%
# 2.利用 Pyecharts 将第(1)问所得数据作条形图(阅读参考文章 7)，
    #图表标题为“上海各区域平均价格”(提示: 最后用 render_notebook()渲染显示出图片);

x = df_avg.index.tolist()
y = df_avg["区域平均价格"].tolist()
print(y)

bar = Bar().add_xaxis(x) 
bar.add_yaxis("区域平均价格",y) 
bar.set_global_opts(title_opts=opts.TitleOpts(title="条形图"))
bar.reversal_axis() #翻转XY轴，将柱状图转换为条形图
bar.render_notebook()
# Out:
# [19304.82, 23662.13, 36461.72, 36587.69, 37078.86, 42577.8, 49080.59, 55413.06, 57943.13, 62726.67, 66165.35, 72099.62, 74304.77, 75395.94, 95015.09]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f09cf2a3db6244038f27230026fab9de" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f09cf2a3db6244038f27230026fab9de = echarts.init(
#                     document.getElementById('f09cf2a3db6244038f27230026fab9de'), 'white', {renderer: 'canvas'});
#                 var option_f09cf2a3db6244038f27230026fab9de = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
# ...

# %%
# 3.利用 groupby 函数，以【装修类型】字段进行 groupby，同时结合 agg 聚合函数统计各个区域房源数量;
df_zhuangxiu = df.groupby('装修类型')['区域'].agg({"房源数量":"count"})
df_zhuangxiu
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#        房源数量
# 装修类型
#  其他    5414
#  毛坯    5357
#  简装   22819
#  精装   32425

# %%
# 4.用 Pyecharts 将第(3)问所得数据作饼图(阅读参考文章 7、8)，图表标题为“装修类型占比情况”

x1 = df_zhuangxiu.index.tolist()
y1 = df_zhuangxiu["房源数量"].tolist()
print(y1)

def pie_base():
    from pyecharts import options as opts
    from pyecharts.charts import Page, Pie
    

    c = (
    Pie()
    .add("", [list(z) for z in zip(x1,y1)])
    .set_global_opts(title_opts=opts.TitleOpts(title="装修类型占比情况"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}%"))#格式化标签输出内容
    )
    return c
pie_base().render_notebook()
# Out:
# [5414, 5357, 22819, 32425]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="325081a0344442c5b899cd0710dd6d01" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_325081a0344442c5b899cd0710dd6d01 = echarts.init(
#                     document.getElementById('325081a0344442c5b899cd0710dd6d01'), 'white', {renderer: 'canvas'});
#                 var option_325081a0344442c5b899cd0710dd6d01 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...
